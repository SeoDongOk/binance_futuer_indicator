# %% [markdown]
# # Moving Average

# %%
# 바이낸스 선물 차트로 적용하기 
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import requests
import json
Ticker = 'JUPUSDT' #비트코인, 달러코인 페어
interval = '1m' # 1분봉
startTime = "1721066160000"# 시간지정 유닉스타임
data=requests.get(f"https://fapi.binance.com/fapi/v1/markPriceKlines?symbol={Ticker}&interval={interval}")
dic=json.loads(data.text) # json을 dict타입으로 변환
df= pd.DataFrame(dic,columns=["OpenTime","Open","High","Low","Close","x","CloseTime","x2","x3","x3","x4","x5"]) # DataFrame으로 만들기
df["OpenTime"] = pd.to_datetime(df['OpenTime'], unit='ms')
df.index = df["OpenTime"]
del df["OpenTime"]
using_case = pd.DataFrame(df["Close"])
using_case = using_case.astype('Float32')

## 강의에서 사용된 변수명은 수정하지 않음.
holding = 20
print(f"{holding}분 이동평균선 상향 돌파 Signal")
using_case_rolling=using_case.rolling(holding).mean()
#--------------------------------------------------------------------------------------------start
signal_i_list = []
signal_date_list = []
signal_price_list = []
signal_return_list = []
#--------------------------------------------------------------------------------------------end


for i in range(len(using_case)):
    if i < 1 or i > len(using_case) - holding:
        continue
    prev_date = using_case.index[i-1]
    now_date = using_case.index[i]
    prev_price = using_case["Close"].iloc[i-1]
    current_price = using_case["Close"].iloc[i]
    prev_ma = using_case_rolling["Close"].iloc[i-1]
    current_ma = using_case_rolling["Close"].iloc[i]
    if prev_price < prev_ma and current_price > current_ma and i+holding < len(using_case):
        sell_price = using_case["Close"].iloc[i+holding]
        income = (sell_price-current_price) / current_price*100
        print(f"  - {now_date}  Signal 발생!  매수주가 {current_price:.0f}  ->  매도주가 {sell_price:.0f}  , 수익률 {income:.3f} %")
        #--------------------------------------------------------------------------------------------start
        signal_i_list.append(using_case.index[i])
        signal_date_list.append(now_date)
        signal_price_list.append(current_price)
        signal_return_list.append(income)
        #--------------------------------------------------------------------------------------------end
print(f"총 시그널 발생 횟수: {len(signal_return_list)}, 총 수익률: {sum(signal_return_list)}")
using_case["Close"][20:].plot(figsize=(15,7), label='price');
using_case_rolling["Close"][20:].plot(label='ma');
plt.scatter(x=signal_i_list, y=signal_price_list, marker=10, color='red', s=100 , label='signal');
plt.title(f"{interval} Ma Golden Cross Method")
plt.legend();
# Out:
# 20분 이동평균선 상향 돌파 Signal
#   - 2024-07-21 23:52:00  Signal 발생!  매수주가 1  ->  매도주가 1  , 수익률 0.240 %
#   - 2024-07-22 00:04:00  Signal 발생!  매수주가 1  ->  매도주가 1  , 수익률 -0.429 %
#   - 2024-07-22 00:35:00  Signal 발생!  매수주가 1  ->  매도주가 1  , 수익률 -0.402 %
#   - 2024-07-22 00:40:00  Signal 발생!  매수주가 1  ->  매도주가 1  , 수익률 -0.551 %
#   - 2024-07-22 00:50:00  Signal 발생!  매수주가 1  ->  매도주가 1  , 수익률 -0.268 %
#   - 2024-07-22 01:08:00  Signal 발생!  매수주가 1  ->  매도주가 1  , 수익률 -0.100 %
#   - 2024-07-22 01:12:00  Signal 발생!  매수주가 1  ->  매도주가 1  , 수익률 -0.419 %
#   - 2024-07-22 01:20:00  Signal 발생!  매수주가 1  ->  매도주가 1  , 수익률 -0.410 %
#   - 2024-07-22 02:14:00  Signal 발생!  매수주가 1  ->  매도주가 1  , 수익률 1.006 %
#   - 2024-07-22 02:48:00  Signal 발생!  매수주가 1  ->  매도주가 1  , 수익률 -0.761 %
#   - 2024-07-22 02:56:00  Signal 발생!  매수주가 1  ->  매도주가 1  , 수익률 -0.747 %
#   - 2024-07-22 03:19:00  Signal 발생!  매수주가 1  ->  매도주가 1  , 수익률 -0.348 %
#   - 2024-07-22 03:33:00  Signal 발생!  매수주가 1  ->  매도주가 1  , 수익률 -0.436 %
#   - 2024-07-22 03:46:00  Signal 발생!  매수주가 1  ->  매도주가 1  , 수익률 -0.292 %
#   - 2024-07-22 04:06:00  Signal 발생!  매수주가 1  ->  매도주가 1  , 수익률 0.041 %
#   - 2024-07-22 04:31:00  Signal 발생!  매수주가 1  ->  매도주가 1  , 수익률 -0.108 %
#   - 2024-07-22 04:49:00  Signal 발생!  매수주가 1  ->  매도주가 1  , 수익률 -0.755 %
#   - 2024-07-22 05:53:00  Signal 발생!  매수주가 1  ->  매도주가 1  , 수익률 0.126 %
#   - 2024-07-22 06:05:00  Signal 발생!  매수주가 1  ->  매도주가 1  , 수익률 0.119 %
#   - 2024-07-22 06:21:00  Signal 발생!  매수주가 1  ->  매도주가 1  , 수익률 -1.019 %
#   - 2024-07-22 06:24:00  Signal 발생!  매수주가 1  ->  매도주가 1  , 수익률 -0.880 %
#   - 2024-07-22 06:52:00  Signal 발생!  매수주가 1  ->  매도주가 1  , 수익률 -0.968 %
#   - 2024-07-22 06:57:00  Signal 발생!  매수주가 1  ->  매도주가 1  , 수익률 -0.794 %
# 총 시그널 발생 횟수: 23, 총 수익률: -8.15330034820363
